# %% [markdown]
# # 차원의 저주
# ---
# ![image.png](attachment:image.png)

# %% [markdown]
# # 차원 축소의 장점
# ---
# - 학습 데이터 크기를 줄여서 학습 시간절약
# - 불필요한 피처들을 줄여서 모델 성능 향상에 기여
# - 다차원의 데이터를 3차원 이하의 차원 축소를 통해서 시각적으로 보다 쉽게 데이터 패턴 인지

# %% [markdown]
# # 피처 선택과 피처 추출
# ---
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 피처 추출
# ---
# 피처 추출은 기존 피처를 단순 압축이 아닌, 피처를 함축적으로 더 잘 설명할 수 있는 또 다른 공간으로 매핑해 추출하는 것입니다.
# ` `
# ![image.png](attachment:image.png)

# %% [markdown]
# # 차원 축소의 의미
# ---
# - 차원 축소는 다순히 데이터 압축을 의미하는 것이 아니라. 더 중요한 의미는 차원 축소를 통해 좀 더 데이터를 잘 설명할 수 있는 잠재적인 요소를 추출하는 데에 있다.
#     - 추천 엔진
#     - 이미지 분류 및 변환
#     - 문서 토픽 모델링
